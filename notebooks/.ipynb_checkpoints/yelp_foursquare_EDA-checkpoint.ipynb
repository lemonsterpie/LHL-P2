# %%
# imports

import os 
import requests 
import pandas as pd
import numpy as np
import json

# %%
# Vancouver bike stations from part 1: 

van_bikes = pd.read_csv('van_bikes.csv')

# %% [markdown]
# # Foursquare

# %%
# Category IDs:

restaurant_id = '4d4b7105d754a06374d81259'
bar_id = '4bf58dd8d48988d116941735'
pilates_id = '5744ccdfe4b0c0459246b4b2'
yoga_id = '4bf58dd8d48988d102941735'

workout_id = f'{pilates_id},{yoga_id}'

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
url = 'https://api.foursquare.com/v3/places/search?'
api_key = os.environ['FOURSQUARE_API_KEY']
headers = {'Accept': 'application/json'}
headers['Authorization'] = api_key

restaurants = []
workouts = []

for row in van_bikes.itertuples(index=False):
    lat = row.latitude
    long = row.longitude 
    ll = f'{lat},{long}'
    
    r_params = {'ll': ll,
                  'radius': 1000,
                  'categories': restaurant_id}
    w_params = {'ll': ll, 
              'radius': 1000,
              'categories': workout_id}
    
    r_result = requests.get(url, headers=headers, params=r_params)
    r_data = r_result.json()
    r_df = pd.json_normalize(r_data['results'])
    r_df = r_df.rename(columns={'geocodes.main.latitude': 'latitude',
                                'geocodes.main.longitude': 'longitude',
                                'location.address': 'address',
                                'location.country': 'country',
                                'location.locality': 'locality',
                                'location.postcode': 'postcode'})
    restaurants.append(r_df)

    w_result = requests.get(url, headers=headers, params=w_params)
    w_data = w_result.json()
    w_df = pd.json_normalize(w_data['results'])
    w_df = w_df.rename(columns={'geocodes.main.latitude': 'latitude',
                                'geocodes.main.longitude': 'longitude',
                                'location.address': 'address',
                                'location.country': 'country',
                                'location.locality': 'locality',
                                'location.postcode': 'postcode'})
    workouts.append(w_df)

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
for i, r in enumerate(restaurants):
    restaurants[i] = restaurants[i][['fsq_id', 'distance', 'name', 'latitude', 'longitude', 'address']]

# For each bike station, I the details I am intersted in are: 
# distances and names of nearest/furthest restaurant and workout
# avg distance of restaurants and workouts around 
# total number or workouts nearby

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
nearest_rdists = []
nearest_rnames = []
furthest_rdists = []
furthest_rnames = []
avg_rdists = []
nearest_wdists = []
nearest_wnames = []
furthest_wdists = []
furthest_wnames = []
avg_wdists = []
nearby_workouts = []

for i, row in van_bikes.iterrows():
    r_df = restaurants[i]
    nearest_rdist = r_df['distance'].min()
    nearest_rname = r_df.sort_values('distance').iloc[0]['name']
    furthest_rdist = r_df['distance'].max()
    furthest_rname = r_df.sort_values('distance', ascending=False).iloc[0]['name']
    avg_rdist = round((sum(list(r_df['distance'])) / len(r_df)), 2)

    w_df = workouts[i]
    if 'distance' in w_df.columns:
        nearest_wdist = w_df['distance'].min()
        furthest_wdist = w_df['distance'].max()
        avg_wdist = round(sum(list(w_df['distance'])) / len(w_df), 2)
    else:
        nearest_wdist = None
        furthest_wdist = None
        avg_wdist = None
        
    if 'name' in w_df.columns: 
        nearest_wname = w_df.sort_values('distance').iloc[0]['name']
        furthest_wname = w_df.sort_values('distance', ascending=False).iloc[0]['name']
    else:
        nearest_wname = None
        furthest_wname = None

    workouts_nearby = len(w_df)

    nearest_rdists.append(nearest_rdist)
    nearest_rnames.append(nearest_rname)
    furthest_rdists.append(furthest_rdist)
    furthest_rnames.append(furthest_rname)
    avg_rdists.append(avg_rdist)
    nearest_wdists.append(nearest_wdist)
    nearest_wnames.append(nearest_wname)
    furthest_wdists.append(furthest_wdist)
    furthest_wnames.append(furthest_wname)
    avg_wdists.append(avg_wdist)
    nearby_workouts.append(workouts_nearby)

# %%
foursquare_df = pd.DataFrame({'name': van_bikes['name'],
              'timestamp': van_bikes['timestamp'],
              'free_bikes': van_bikes['free_bikes'],
              'empty_slots': van_bikes['empty_slots'],
              'nearest_rdist': nearest_rdists,
              'nearest_rname': nearest_rnames,
              'furthest_rdist': furthest_rdists,
              'furthest_rname': furthest_rnames,
              'avg_rdist': avg_rdists,
              'nearest_wdist': nearest_wdists,
              'nearest_wname': nearest_wnames,
              'furthest_wdist': furthest_wdists,
              'furthest_wname': furthest_wnames,
              'avg_wdist': avg_wdists,
              'nearby_workouts': nearby_workouts})

# %%
foursquare_df.head()
# Out:
#                     name                    timestamp  free_bikes  \
# 0       Chilco & Barclay  2025-04-17T00:24:45.486341Z           5
# 1   St George & Broadway  2025-04-17T00:24:45.944688Z           0
# 2  Britannia Parking Lot  2025-04-17T00:24:45.920383Z           0
# 3        Morton & Denman  2025-04-17T00:24:45.074554Z          21
# 4    Thornton & National  2025-04-17T00:24:45.920601Z           9
#
#    empty_slots  nearest_rdist              nearest_rname  furthest_rdist  \
# 0           13            308       Kingyo Izakaya 金魚居酒屋             869
# 1           14            341               12 Kings Pub             906
# 2           14            160  The Downlow Chicken Shack             506
# 3            4             89             Bayside Lounge             668
# 4            5            552                   Torafuku             902
#
#             furthest_rname  avg_rdist  nearest_wdist  \
# 0             The Inukshuk      518.7          366.0
# 1      33 Acres Brewing Co      615.0          329.0
# 2      Via Tevere Pizzeria      336.3          201.0
# 3  Hokkaido Ramen Santouka      297.2          537.0
# 4               Keefer Bar      742.8          675.0
#
#                    nearest_wname  furthest_wdist       furthest_wname  \
# 0           Oxygen Yoga West End           862.0  Royal Private Coach
# 1  Vancouver Pilates Process Inc           940.0        Dharma Temple
# 2   Bikram Yoga Commercial Drive           836.0            Dharmalab
# 3           Oxygen Yoga West End           981.0  Royal Private Coach
# 4                Radha Vancouver           917.0              Stretch
#
#    avg_wdist  nearby_workouts
# 0     649.00                5
# 1     704.50               10
# 2     442.00                4
# 3     735.75                4
# 4     775.00                3

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
url = 'https://api.yelp.com/v3/businesses/search?categories=&sort_by=best_match&limit=10'

headers = {'Accept': 'application/json'}
headers['Authorization'] = api_key
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 2
#       1 url = 'https://api.yelp.com/v3/businesses/search?categories=&sort_by=best_match&limit=10'
# ----> 2 api_key = os.environ['YELP_API_KEY']
#       3 headers = {'Accept': 'application/json'}
#       4 headers['Authorization'] = api_key
#
# File ~\anaconda3\envs\lhl_env\lib\os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'YELP_API_KEY'

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
api_key = os.environ["YELP_API_KEY"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 api_key = os.environ["YELP_API_KEY"]
#
# File ~\anaconda3\envs\lhl_env\lib\os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'YELP_API_KEY'

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
print(os.environ.keys())
# Out:
# KeysView(environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\sherr\\AppData\\Roaming', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'DESKTOP-PF10FT4', 'COMSPEC': 'C:\\Windows\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'lhl_env', 'CONDA_EXE': 'C:\\Users\\sherr\\anaconda3\\Scripts\\conda.exe', 'CONDA_PREFIX': 'C:\\Users\\sherr\\anaconda3\\envs\\lhl_env', 'CONDA_PREFIX_1': 'C:\\Users\\sherr\\anaconda3', 'CONDA_PROMPT_MODIFIER': '(lhl_env) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\sherr\\anaconda3\\python.exe', 'CONDA_ROOT': 'C:\\Users\\sherr\\anaconda3', 'CONDA_SHLVL': '2', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'FOURSQUARE_API_KEY': 'fsq3y04Dj2eHgzXPU++vlKx2pQP/QWlpEXUsDjQxtQBfqZ8=', 'GIT_LFS_PATH': 'C:\\Program Files\\Git LFS', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\sherr', 'LOCALAPPDATA': 'C:\\Users\\sherr\\AppData\\Local', 'LOGONSERVER': '\\\\DESKTOP-PF10FT4', 'NUMBER_OF_PROCESSORS': '12', 'ONEDRIVE': 'C:\\Users\\sherr\\OneDrive', 'ONEDRIVECONSUMER': 'C:\\Users\\sherr\\OneDrive', 'OS': 'Windows_NT', 'PATH': 'C:\\Users\\sherr\\anaconda3\\envs\\lhl_env;C:\\Users\\sherr\\anaconda3\\envs\\lhl_env\\Library\\mingw-w64\\bin;C:\\Users\\sherr\\anaconda3\\envs\\lhl_env\\Library\\usr\\bin;C:\\Users\\sherr\\anaconda3\\envs\\lhl_env\\Library\\bin;C:\\Users\\sherr\\anaconda3\\envs\\lhl_env\\Scripts;C:\\Users\\sherr\\anaconda3\\envs\\lhl_env\\bin;C:\\Users\\sherr\\anaconda3\\condabin;C:\\Users\\sherr\\anaconda3;C:\\Users\\sherr\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\sherr\\anaconda3\\Library\\usr\\bin;C:\\Users\\sherr\\anaconda3\\Library\\bin;C:\\Users\\sherr\\anaconda3\\Scripts;C:\\Program Files (x86)\\Razer Chroma SDK\\bin;C:\\Program Files\\Razer Chroma SDK\\bin;C:\\Program Files (x86)\\Razer\\ChromaBroadcast\\bin;C:\\Program Files\\Razer\\ChromaBroadcast\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;C:\\Program Files\\dotnet;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Users\\sherr\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Windows\\system32\\config\\systemprofile\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Program Files\\Git\\cmd;C:\\Program Files\\Git LFS;C:\\Users\\sherr\\anaconda3;C:\\Users\\sherr\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\sherr\\anaconda3\\Library\\usr\\bin;C:\\Users\\sherr\\anaconda3\\Library\\bin;C:\\Users\\sherr\\anaconda3\\Scripts;C:\\Users\\sherr\\AppData\\Local\\Programs\\Python\\Launcher;C:\\Users\\sherr\\AppData\\Local\\Microsoft\\WindowsApps', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'AMD64 Family 23 Model 113 Stepping 0, AuthenticAMD', 'PROCESSOR_LEVEL': '23', 'PROCESSOR_REVISION': '7100', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PROMPT': '(lhl_env) $P$G', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules', 'PUBLIC': 'C:\\Users\\Public', 'SESSIONNAME': 'Console', 'SSL_CERT_FILE': 'C:\\Users\\sherr\\anaconda3\\Library\\ssl\\cacert.pem', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\Windows', 'TEMP': 'C:\\Users\\sherr\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\sherr\\AppData\\Local\\Temp', 'USERDOMAIN': 'DESKTOP-PF10FT4', 'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-PF10FT4', 'USERNAME': 'sherr', 'USERPROFILE': 'C:\\Users\\sherr', 'VBOX_HWVIRTEX_IGNORE_SVM_IN_USE': '1', 'WINDIR': 'C:\\Windows', '__CONDA_OPENSLL_CERT_FILE_SET': '"1"', 'JPY_SESSION_NAME': 'C:\\Users\\sherr\\LHL classwork\\LHL-P2\\notebooks\\yelp_foursquare_EDA.ipynb', 'JPY_INTERRUPT_EVENT': '4220', 'IPY_INTERRUPT_EVENT': '4220 ...

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Get the top 10 restaurants according to their rating
